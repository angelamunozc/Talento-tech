# %% [markdown]
# <a href="https://colab.research.google.com/github/angelamunozc/Talento-tech/blob/main/experiencia/Ud_1_Ejercicios_pr%C3%A1cticos_Keras_Red_neuronal_para_clasificacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar bibliotecas

import keras
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
# generar un conjunto de datos de clasificacion sintetico

X, y = make_classification(n_samples=1000, n_features=5, n_classes=2)

# %%
# dividir los datos en conjunto de entrenamiento y prueba

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# convertir las etiquetas a codificacion one-hot

y_train_categorical = keras.utils.to_categorical(y_train)
y_test_categorical = keras.utils.to_categorical(y_test)

# %%
# crear una instancia de un modelo secuencial de keras

model = keras.models.Sequential()

# %%
# añadir una capa oculta con 10 neuonas y activacion RELU

model.add(keras.layers.Dense(10, activation='relu'))

# añadir una capa de salida con 2 neuronas (una para cada clase ) y
#activacion softmax
model.add(keras.layers.Dense(2, activation='softmax'))

# %%
#compliar el modelo

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# entrenar el modelo

model.fit(X_train, y_train_categorical, epochs=10, batch_size=32,
          validation_data=(X_test, y_test_categorical))
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5029 - loss: 0.6932 - val_accuracy: 0.4750 - val_loss: 0.6937
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5399 - loss: 0.6925 - val_accuracy: 0.4750 - val_loss: 0.6942
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5128 - loss: 0.6929 - val_accuracy: 0.4750 - val_loss: 0.6939
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5125 - loss: 0.6930 - val_accuracy: 0.4750 - val_loss: 0.6935
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4989 - loss: 0.6932 - val_accuracy: 0.4750 - val_loss: 0.6939
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5260 - loss: 0.6926 - val_accuracy: 0.4750 - val_loss: 0.6940
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5373 - loss: 0.6923 - val_accuracy: 0.4750 - val_loss: 0.6940
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5200 - loss: 0.6928 - val_accuracy: 0.4750 - val_loss: 0.6940
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4911 - loss: 0.6935 - val_accuracy: 0.4750 - val_loss: 0.6934
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5141 - loss: 0.6931 - val_accuracy: 0.4750 - val_loss: 0.6937

# %%
# evaluar el modelo en el conjunto de prueba

loss, accuracy = model.evaluate(X_test, y_test_categorical)

#impresion de resultados
print('Perdida en el conjunto de prueba:', loss)
print('Precision en el conjunto de prueba:', accuracy)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4084 - loss: 0.6951
# Perdida en el conjunto de prueba: 0.6937205791473389
# Precision en el conjunto de prueba: 0.4749999940395355
